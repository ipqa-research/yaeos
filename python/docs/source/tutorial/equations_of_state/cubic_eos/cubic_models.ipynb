# %% [markdown]
# ## Generic Cubic Equation of State

# %% [markdown]
# ## Peng-Robinson (1976)

# %% [markdown]
# ## Peng-Robinson (1978)

# %% [markdown]
# ## Soave-Redlich-Kwong

# %% [markdown]
# ## RKPR

# %% [markdown]
# ## Predictive Soave-Redlich-Kwong
