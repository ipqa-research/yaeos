# %%
import matplotlib.pyplot as plt

import pandas as pd

# %%
df = pd.read_csv("asd.csv", sep=" ")

# %%
dew = df[df["type"] == "dew"]
bubble = df[df["type"] == "bubble"]
crit = df[df["type"] == "critical"]

# %%
t_bub = [241.0, 252.4, 262.0, 272.3, 283.1, 295.6, 309.8, 326.9, 344.0, 361.1, 374.1, 395.2, 408.3, 419.1, 433.9, 451.0, 469.2, 484.0, 501.1, 513.6, 524.4]
p_bub = [0.8238, 1.236, 1.442, 1.854, 2.471, 3.089, 3.913, 4.943, 6.178, 7.414, 8.650, 10.71, 12.15, 13.59, 15.45, 17.92, 21.01, 23.89, 27.39, 30.07, 32.33]

t_dew = [368.5, 387.8, 406.6, 420.8, 437.3, 450.4, 464.1, 474.9, 489.1, 497.6, 507.9, 515.9, 524.4, 531.2]
p_dew= [0.8238, 1.854, 2.883, 3.913, 5.561, 7.208, 9.474, 11.53, 14.83, 17.09, 20.18, 23.07, 26.57, 30.48]

t_crit = [532.9]
p_crit = [32.95]

# %%
plt.plot(dew["T"], dew["P"])
plt.plot(bubble["T"], bubble["P"])
plt.plot(crit["T"], crit["P"], marker="s")
plt.plot(t_bub, p_bub, linestyle=None, marker="x", markeredgecolor="black")
plt.plot(t_dew, p_dew, linestyle=None, marker="x", markeredgecolor="black")
